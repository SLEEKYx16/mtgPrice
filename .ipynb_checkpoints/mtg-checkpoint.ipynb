# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import datetime

## Visulization
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
## Load the training and test dataset

timeAV_df = pd.read_csv("./modern/Aether Vial.csv")
timeAR_df = pd.read_csv("./modern/Arcbound Ravager.csv")
timeAR_df = pd.read_csv("./modern/Arid Mesa.csv")
timeAR_df = pd.read_csv("./modern/Azusa, Lost but Seeking.csv")
timeAR_df = pd.read_csv("./modern/Bitterblossom.csv")
timeAR_df = pd.read_csv("./modern/Blackcleave Cliffs.csv")
timeAR_df = pd.read_csv("./modern/Blightsteel Colossus.csv")
timeAR_df = pd.read_csv("./modern/Blood Moon.csv")
timeAR_df = pd.read_csv("./modern/Bloom Tender.csv")
timeAR_df = pd.read_csv("./modern/Cavern of Souls.csv")
timeAR_df = pd.read_csv("./modern/Celestial Colonnade.csv")
timeAR_df = pd.read_csv("./modern/Chalice of the Void.csv")
Chandra_Torch_of_Defiance_df = pd.read_csv("./modern/Chandra, Torch of Defiance.csv")
Crucible_of_Worlds_df = pd.read_csv("./modern/Crucible of Worlds.csv")
Cryptic_Command_df = pd.read_csv("./modern/Cryptic Command.csv")
Damnation_df = pd.read_csv("./modern/Damnation.csv")
Dark_Confidant_df = pd.read_csv("./modern/Dark Confidant.csv")
Dark_Depths_df = pd.read_csv("./modern/Dark Depths.csv")
Doubling_df = pd.read_csv("./modern/Doubling Season.csv")
Emrakul_df = pd.read_csv("./modern/Emrakul, the Aeons Torn.csv")

# %%
timeAR_df
# Out:
#             date  Arcbound Ravager value
# 0     2010-09-16                   13.66
# 1     2010-09-19                   13.66
# 2     2010-09-20                   13.66
# 3     2010-09-21                   13.66
# 4     2010-09-22                   13.66
# 5     2010-09-23                   13.66
# 6     2010-09-24                   13.66
# 7     2010-09-25                   13.66
# 8     2010-09-26                   13.66
# 9     2010-09-27                   13.66
# 10    2010-09-28                   13.66
# 11    2010-09-29                   13.66
# 12    2010-09-30                   13.66
# 13    2010-10-01                   13.66
# 14    2010-10-02                   13.66
# 15    2010-10-03                   13.66
# 16    2010-10-04                   13.41
# 17    2010-10-05                   13.66
# 18    2010-10-06                   13.66
# 19    2010-10-07                   13.66
# 20    2010-10-08                   13.66
# 21    2010-10-09                   13.66
# ...

# %%
timeAV_df.set_index('date')
timeAR_df.set_index('date')
df = timeAV_df.merge(timeAR_df,  how='outer')

df
# Out:
#             date  Aether Vial value  Arcbound Ravager value
# 0     2013-03-09              16.59                   24.65
# 1     2013-03-10              16.53                   24.65
# 2     2013-03-11              16.59                   24.69
# 3     2013-03-12              16.53                   24.84
# 4     2013-03-13              16.59                   24.98
# 5     2013-03-14              16.47                   24.98
# 6     2013-03-15              16.45                   24.97
# 7     2013-03-16              16.41                   24.98
# 8     2013-03-17              16.43                   24.97
# 9     2013-03-18              16.59                   24.98
# 10    2013-03-19              16.51                   24.95
# 11    2013-03-20              16.47                   24.97
# 12    2013-03-21              16.55                   24.98
# 13    2013-03-22              16.55                   24.98
# 14    2013-03-23              16.36                   24.98
# ...

# %%
# Out:
# 0      2013-03-09
# 1      2013-03-10
# 2      2013-03-11
# 3      2013-03-12
# 4      2013-03-13
# 5      2013-03-14
# 6      2013-03-15
# 7      2013-03-16
# 8      2013-03-17
# 9      2013-03-18
# 10     2013-03-19
# 11     2013-03-20
# 12     2013-03-21
# 13     2013-03-22
# 14     2013-03-23
# 15     2013-03-24
# 16     2013-03-25
# 17     2013-03-26
# 18     2013-03-27
# 19     2013-03-28
# 20     2013-03-29
# 21     2013-03-30
# 22     2013-03-31
# 23     2013-04-01
# 24     2013-04-02
# 25     2013-04-03
# 26     2013-04-04
# 27     2013-04-05
# 28     2013-04-06
# 29     2013-04-07
#           ...
# 2655   2013-03-01
# 2656   2013-03-02
# 2657   2013-03-03
# 2658   2013-03-04
# 2659   2013-03-05
# 2660   2013-03-06
# 2661   2013-03-07
# 2662   2013-03-08
# 2663   2015-01-12
# 2664   2015-01-17
# 2665   2015-01-28
# 2666   2015-02-03
# 2667   2015-02-09
# 2668   2015-05-18
# 2669   2015-09-23
# 2670   2016-01-08
# 2671   2016-01-11
# 2672   2016-01-29
# 2673   2016-02-11
# ...

# %%
x = np.array(pd.to_datetime(df['date'], format="%Y-%m-%d"))
y = df['Aether Vial value']
a = df['Arcbound Ravager value']

plt.plot(x,y)
plt.plot(x,a)

plt.show()

# %%
from bs4 import BeautifulSoup
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import requests

# %%
lookupDate = '2018-02-22'

url = 'magic.wizards.com/en/articles/archive/mtgo-standings/competitive-standard-constructed-league-'+ lookupDate
r  = requests.get("http://" +url)

data = r.text

soup = BeautifulSoup(data)
playedCards = []
for card in soup.findAll('a', {'class':'deck-list-link'}):
    if card.string not in playedCards:
        playedCards.append(card.string)
        
        
df = pd.DataFrame({'Name': playedCards})

df
# Out:
# C:\Users\Max\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 184 of the file C:\Users\Max\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
#                            Name
# 0    Chandra, Torch of Defiance
# 1                 Bomat Courier
# 2           Hazoret the Fervent
# 3                    Pia Nalaar
# 4            Rekindling Phoenix
# 5           Scrapheap Scrounger
# 6            Toolcraft Exemplar
# 7              Walking Ballista
# 8                Cut // Ribbons
# ...
